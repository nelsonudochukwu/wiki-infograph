# %% [markdown]
# # Create tool for informative infographics from structured information from Wikimedia projects - Task A
#
# This notebook provides information on accessing and visualizing article pageviews in the Portuguese Wikipedia.
#
# The objectives are:
# 1. to read and understand the Wikimedia API documentation;
# 2. to complete the gaps in the code below, coding functions about the most viewed articles in the Portuguese Wikipedia;
# 3. to create an animated visualization of the data you gathered.

# %%
# TODO: execute this row and type your Wikimedia username below
username = input("Type your Wikimedia username:")
# Out:
# Type your Wikimedia username: Udonels

# %% [markdown]
# ### Wikimedia API documentation
#
# Here you can find the documentation for the Wikimedia API: https://wikimedia.org/api/rest_v1/#/.
#
# You do not need to read every function there, but focus on the *PageViews data* section.
#
# **Objective:** *(1) to read and understand the documentation.*

# %% [markdown]
# ### Completing the gaps
#
# Based on your knowledges of Python and the documentation for the Wikimedia API, please implement below:
# * A function to get a list of the most viewed articles in the Portuguese Wikipedia for the month of January, ordered from the most viewed to the least one;
#   * Be aware that there are false positives, so you will need to remove rows of data of other projects other than the Portuguese Wikipedia;
# * A function to get a dataframe of the most viewed articles in the Portuguese Wikipedia for the period of January 1st, 2024 and February 29th, 2024
#   * The result dataframe should have the folowing structure:
#     * Each row represents an article (A);
#     * Each column header (besides the articles names) represents a day of this period (D);
#     * The cells values store the visualization of the article A on the date D.
#
#
# **Objective:** *(2) to complete the gaps in the code below, coding functions about the most viewed articles in the Portuguese Wikipedia.*

# %% [markdown]
# ### ADDRESSING THE FEEDBACK RECEIVED

# %% [markdown]
# I effected changes to my assigned tasks as required by my mentor, Eder Porto. The changes I made are as follows:
#
# **4.3: You need to filter out pages that are not articles.**
#
# I checked and updated my articles list to exclude false positives based on the Wikimedia information here (https://en.wikipedia.org/wiki/Wikipedia:What_is_an_article%3F): An article belongs to the main namespace and doesn't include a prefix with a ':' as guided by my mentor, Eder Porto.
#
# **4.5: The numbers in your dataframe and video seem off. Please review that. Facebook, for example, had 350 thousand in all of January**
#
# I updated my dataframe (for the chart race) containing the most viewed articles in pt_wiki from 20240101 to 20240229 with its correct views per timestamp as guided by my mentor, Eder Porto after an understanding that the *views required user-agents and not all-agents,* and articles belong to the main namespace.
#
# **I like the async approach, because it saves a lot of time!**
#
# Lastly, I improved the computation time in making numerous requests to ~5 seconds after Eder Porto's invaluable feedback and acknowledgment of my async approach.

# %%
# TODO: add libraries as necessary
import pandas as pd
import asyncio
import concurrent.futures
import httpx
import nest_asyncio
import requests
import time
import warnings
import json
import logging
from urllib.parse import quote
from datetime import datetime, timedelta
from IPython.display import Video
from typing import List

pd.set_option("display.max_rows", 100)
print('done')
# Out:
# done

# %% [markdown]
# ## Get a list of the most viewed articles in the Portuguese Wikipedia for any month.

# %% [markdown]
# ### a. Function to get the most viewed pt_wiki per month

# %%
# Map month name to a number sequentially
MONTH_NAME_TO_NUMBER = {
    "January": "01",
     "February": "02"
    # Add other months as needed
}

def most_viewed_ptwiki(months: List[str]) -> List[str]:
    """
    This function retrieves the most viewed articles on Portuguese Wikipedia for a given list of months.
    
    Parameters:
    - months (List[str]): A list of month names for which to fetch article views.
    
    Returns:
    - List[str]: A list of article titles sorted by views in descending order.
    """

    # Define user-agents to allow batch download
    user_agent = "nelson.ifechukwu@gmail.com"
    headers = {"User-Agent": user_agent}

    # Define a base URL for interacting with the Wikimedia API
    BASE_URL = "https://wikimedia.org/api/rest_v1/metrics/pageviews/top/pt.wikipedia.org/all-access/2024"

    # Define a dictionary to store {articles : views}
    all_articles_and_views = {}

    # Go through each month passed in the parameters
    for each_month in months:
        # Get article views for the specified month
        month_number = MONTH_NAME_TO_NUMBER.get(each_month)
        if month_number is not None:
            url = f"{BASE_URL}/{month_number}/all-days"
            response = requests.get(url, headers=headers)

            # Check if the request is successful
            try:
                response.raise_for_status()
                data = response.json()
            except requests.RequestException as e:
                raise ValueError(f"Error in fetching data for {each_month}: {e}")

            # Get all articles and corresponding views
            items = data.get('items', [])
            if items:
                project = items[0].get('project', '')
                articles = items[0].get('articles', [])
                for article_info in articles:
                    article_title = article_info.get('article', '')
                    views = article_info.get('views', 0)
                    all_articles_and_views[article_title] = all_articles_and_views.get(article_title, 0) + views
                    # all_articles_and_views[article_title] = views
            else:
                raise ValueError(f"No data available for {each_month}")
        else:
            raise ValueError(f"{each_month} is not a month")

    # Sort all articles by views in descending order
    all_sorted_articles_and_views = sorted(
        all_articles_and_views.items(), key=lambda items: items[1], reverse=True)

    # Return only the sorted articles in the dictionary
    all_sorted_articles = [element[0] for element in all_sorted_articles_and_views]
    return all_sorted_articles

# %% [markdown]
# ### b. Function to remove false positives

# %%
#According to the definition of an article here, https://en.wikipedia.org/wiki/Wikipedia:What_is_an_article%3F
#An article occupies the mainspace pages and doesn't include prefixes with :
#Hence, we'll remove titles with : in them
def remove_false_positives(article_list: List[str]) -> List[str]:
    """
    This function accepts a list of strings and removes any string with ':' in it

    Returns: It returns the modified list
    """
    
    # Create a copy of the 'article_list' to avoid list modification during iteration that can lead to potential incomplete removal
    article_list_copy = article_list[:]  
    for each_article in article_list_copy:
        if ':' in each_article:
            # Remove from original list
            article_list.remove(each_article)  
    return article_list

# %% [markdown]
# ### c. Function to get the most viewed pt_wiki articles for January

# %%
# Get a sorted list of the most viewed articles in Portuguese Wiki in January
def most_viewed_ptwiki_jan() -> List[str]:
    sorted_articles_jan = most_viewed_ptwiki(["January"])

    #Dealing with falsepositives
    sorted_articles_jan = remove_false_positives(sorted_articles_jan)

    return sorted_articles_jan

# %% [markdown]
# ### c (i). showing the most viewed pt_wiki articles for January

# %%
# TODO: add parameters as necessary and execute this block
top_viewed_list = most_viewed_ptwiki_jan()
top_viewed_list
# Out:
# ['XXx',
#  'Fotos_dos_Mamonas_Assassinas_mortos',
#  'Voo_Força_Aérea_Uruguaia_571',
#  'Facebook',
#  'Zagallo',
#  'Porno_Graffitti',
#  'Renascer',
#  'ChatGPT',
#  'Yasmin_Brunet',
#  'Cleópatra',
#  'Griselda_Blanco',
#  'AMBEV',
#  'Renascer_(2024)',
#  'YouTube',
#  'Copa_São_Paulo_de_Futebol_Júnior',
#  'Napoleão_Bonaparte',
#  'Sony_Channel',
#  'Rodriguinho_(cantor)',
#  'Brasil',
#  'Twitter',
#  'Ano-novo',
#  'João_Carreiro_&_Capataz',
#  'TV_Globo',
#  'Canal_Brasil',
#  'Jeffrey_Epstein',
#  'Domingos_Brazão',
#  'Cristiano_Ronaldo',
#  'Instagram',
#  'Mamonas_Assassinas',
#  'Louis_Joseph_César_Ducornet',
#  'Big_Brother_Brasil_24',
#  'Campeonato_Africano_das_Nações',
#  'Copa_São_Paulo_de_Futebol_Júnior_de_2024',
#  'Franz_Beckenbauer',
#  'Carlos_Alberto_Parreira',
#  'Dorival_Júnior',
#  'Thiago_Carpini',
#  'Marcinho_VP',
#  'Robert_Oppenheimer',
#  'Fernando_Parrado',
#  'Wanessa_Camargo',
#  'Vanessa_Lopes',
#  'Campeonato_Paulista_de_Futebol',
#  'Mortes_em_janeiro_de_2024',
#  'Jogo_do_bicho',
#  'São_Paulo',
#  'Roberto_Canessa',
#  'Portugal',
#  'Pablo_Marçal',
#  'Fundação_Padre_Anchieta',
#  'Terra_e_Paixão',
#  'Estados_Unidos',
#  'Lionel_Messi',
#  'MC_Bin_Laden',
#  'RMS_Titanic',
#  'Rafael_Santos_Borré',
#  'Real_Madrid_Club_de_Fútbol',
#  'Clube_de_Regatas_do_Flamengo',
#  'Neymar',
#  'Campeonato_Africano_das_Nações_de_2023',
#  'Paraíso_Tropical',
#  'São_Paulo_Futebol_Clube',
#  'Mercado_Livre',
#  'Pelé',
#  'Travesti',
#  'Éverton_Ribeiro',
#  'Sexo',
#  'Elon_Musk',
#  'Caso_Richthofen',
#  'Josefina_de_Beauharnais',
#  'Três_Reis_Magos',
#  'Big_Brother_Brasil',
#  'Lista_de_códigos_telefónicos',
#  'Ronaldo_Nazário',
#  'Dinho_(cantor)',
#  'WhatsApp',
#  'Leonard_Bernstein',
#  'Homem',
#  'Percy_Jackson_&_the_Olympians',
#  'Dado_Dolabella',
#  'Lista_de_presidentes_do_Brasil',
#  'Ronaldinho_Gaúcho',
#  'Netflix',
#  'Isabel_II_do_Reino_Unido',
#  'Terra',
#  'Solo_Leveling',
#  'Liga_dos_Campeões_da_UEFA',
#  'Rio_de_Janeiro',
#  'Daniel_Erthal',
#  'Sport_Club_Corinthians_Paulista',
#  'Girona_Futbol_Club',
#  'Luíza_Brunet',
#  'Silvio_Santos',
#  'José_Mourinho',
#  'Cacau_(telenovela)',
#  'Mulheres_de_Areia_(1993)',
#  'Tacacá',
#  'Campeonato_Carioca_de_Futebol',
#  'Lucas_Alario',
#  'Jandira_Martini',
#  'Bet365',
#  'The_Chosen',
#  'Elvis_Presley',
#  'Albert_Einstein',
#  'Luiz_Inácio_Lula_da_Silva',
#  '2024',
#  'Angola',
#  'Segunda_Guerra_Mundial',
#  'Sociedade_Esportiva_Palmeiras',
#  'Ricardo_Lewandowski',
#  'Oppenheimer_(filme)',
#  'Caixa_Econômica_Federal',
#  'Taylor_Swift',
#  'Romário',
#  'Super_Bowl',
#  'XVideos',
#  'Copa_do_Mundo_FIFA',
#  'Humberto_Carrão',
#  'Iémen',
#  'Alive_(1993)',
#  'Matías_Viña',
#  'São_Paulo_(estado)',
#  'Luiz_Gustavo_(futebolista,_1987)',
#  'Maçonaria',
#  'Seleção_Brasileira_de_Futebol',
#  'Taça_da_Liga',
#  'Equador',
#  'Bonnie_e_Clyde',
#  'Júlio_Lancellotti',
#  'Margarida_II_da_Dinamarca',
#  'Club_de_Regatas_Vasco_da_Gama',
#  'Eleições_legislativas_portuguesas_de_2024',
#  'Luiza_Brunet',
#  'A',
#  'Vinícius_Júnior',
#  'Canva',
#  'Jürgen_Klopp',
#  'Véspera_de_ano-novo',
#  'Vincent_Aboubakar',
#  'Jesus',
#  'Pablo_Escobar',
#  'Lista_de_episódios_de_Naruto_Shippuden',
#  'Hutis',
#  'Priscilla_Presley',
#  'Rússia',
#  'Lista_de_unidades_federativas_do_Brasil_por_área',
#  'Taiwan',
#  'Primeira_Guerra_Mundial',
#  'Google',
#  'Blogueirinha',
#  'Sport_Lisboa_e_Benfica',
#  'SIC_Novelas',
#  'Leonardo_DiCaprio',
#  'Michael_Jackson',
#  'Japão',
#  'Supercopa_da_Espanha',
#  'Marta_Suplicy',
#  'Israel',
#  'Lista_de_vencedores_do_Super_Bowl',
#  'Fernando_Reges',
#  'Kylian_Mbappé',
#  'Copa_del_Rey',
#  'Países_Baixos',
#  'Mussum',
#  'Douglas_Costa',
#  'Tabela_periódica',
#  'Adolf_Hitler',
#  'Ano_bissexto',
#  'Santos_Futebol_Clube',
#  'Gabigol',
#  'Mortes_em_2024',
#  'Campeonato_Brasileiro_de_Futebol',
#  'Ana_Castela',
#  'Lista_de_municípios_de_São_Paulo_por_população',
#  'Australian_Open',
#  'Titanic_(filme_de_1997)',
#  'Futbol_Club_Barcelona',
#  'Moisés',
#  'Lisa_Marie_Presley',
#  "Ballon_d'Or",
#  'Amazon',
#  'Clima',
#  'Sporting_Clube_de_Portugal',
#  'Xuxa',
#  'Fascismo',
#  'Campeonato_Brasileiro_de_Futebol_de_2024_-_Série_B',
#  'Copa_da_Ásia',
#  'Gmail',
#  'Barry_Keoghan',
#  'One_Piece',
#  'Manchester_City_Football_Club',
#  'Igor_Coronado',
#  'Pornhub',
#  'Hierarquia_militar_do_Brasil',
#  'Paolla_Oliveira',
#  'Copa_da_Inglaterra',
#  'Claudinho_&_Buchecha',
#  'Elis_Regina',
#  'Margarida,_Condessa_de_Snowdon',
#  'OLX',
#  'Echo_(série_de_televisão)',
#  'Pecado_Mortal_(telenovela)',
#  'Cillian_Murphy',
#  'André_Ventura',
#  'XXX_(álbum)',
#  'Agustín_Marchesín',
#  'José_Augusto_(cantor)',
#  'Jannik_Sinner',
#  '2024_na_televisão_brasileira',
#  'Pedro_Nuno_Santos',
#  'XNXX',
#  'Campeonato_Brasileiro_de_Futebol_de_2024_-_Série_A',
#  'National_Basketball_Association',
#  'Carnaval',
#  'França',
#  'Cruzeiro_Esporte_Clube',
#  'Donald_Trump',
#  'Scatman_John',
#  'Roberto_Carlos',
#  'Cabo_Verde',
#  'Carlos_III_do_Reino_Unido',
#  'Leviatã',
#  'Sampaio_Corrêa_Futebol_e_Esporte',
#  'Ayrton_Senna',
#  'Percy_Jackson_and_the_Olympians_(série_de_televisão)',
#  'Cha_Eun-woo',
#  'PC_Siqueira',
#  'Pecado_mortal',
#  'Microsoft',
#  'Campeonato_Gaúcho_de_Futebol',
#  'Fluminense_Football_Club',
#  'La_casa_de_papel',
#  'Alemanha',
#  'Arnold_Schwarzenegger',
#  'Revolução_de_25_de_Abril_de_1974',
#  'Elas_por_Elas_(2023)',
#  'Elas_por_Elas',
#  'Erling_Haaland',
#  'Argentina',
#  'Botafogo_de_Futebol_e_Regatas',
#  'Singapura',
#  'Big_Brother_Brasil_23',
#  'Beto_Carrero',
#  'Enéas_Carneiro',
#  'Kate_Winslet',
#  'Seleção_Angolana_de_Futebol',
#  'Diana,_Princesa_de_Gales',
#  'Lista_de_municípios_de_Minas_Gerais_por_população',
#  'Sinhá_Moça_(2006)',
#  'Fábio_Jr.',
#  'Espanha',
#  'Coreia_do_Norte',
#  'Florida_Cup_de_2024',
#  'Bob_Marley',
#  'Balneário_Camboriú',
#  'Lista_de_filmes_de_maior_bilheteria',
#  'Mia_Khalifa',
#  'Heath_Ledger',
#  'Y',
#  'Lista_de_municípios_do_Paraná_por_população',
#  'Terra_plana',
#  'LeBron_James',
#  'Virginia_Fonseca',
#  'África_do_Sul',
#  'Lista_de_telenovelas_das_nove_da_TV_Globo',
#  'Holocausto',
#  'Lista_de_presidentes_dos_Estados_Unidos',
#  'Evandro_Soldati',
#  'Apple',
#  'Métodos_de_suicídio',
#  'Jujutsu_Kaisen',
#  'Ataques_de_8_de_janeiro_em_Brasília',
#  'Kaká',
#  'Stephen_Hawking',
#  'Vincent_van_Gogh',
#  'Reino_Unido',
#  'Jair_Bolsonaro',
#  'Comando_Vermelho',
#  'Bento_Hinoto',
#  'Sofía_Vergara',
#  'Esporte_Clube_Bahia',
#  'Florianópolis',
#  'Nelson_Wilians',
#  'Rose_DeWitt_Bukater',
#  'Coreia_do_Sul',
#  'Itália',
#  'Supercopa_do_Brasil_de_Futebol',
#  'Curitiba',
#  'Lista_das_maiores_torcidas_de_futebol_do_Brasil',
#  'Dia_de_Reis',
#  'Dinamarca',
#  'AliExpress',
#  'Triângulo_das_Bermudas',
#  'Alan_Ritchson',
#  'Amaury_Lorenzo',
#  'Q',
#  'Jude_Bellingham',
#  'Gaab',
#  'La_Liga',
#  'Google_Maps',
#  'Brasília',
#  'Josep_Guardiola',
#  'Sapo',
#  'Grêmio_Foot-Ball_Porto_Alegrense',
#  'Jann_Mardenborough',
#  'Relação_sexual',
#  'Aster_Brasil_Futebol_Clube',
#  'Pedro_Martins_(treinador)',
#  'Lista_de_partidos_políticos_em_Portugal',
#  'Unidades_federativas_do_Brasil',
#  'Paulo_de_Tarso',
#  'América_(telenovela)',
#  'Minas_Gerais',
#  'Organização_do_Tratado_do_Atlântico_Norte',
#  'Sport_Club_Internacional',
#  'Renée_de_Vielmond',
#  'China',
#  'Suíça',
#  'Martin_Luther_King_Jr.',
#  'Oscar_2024',
#  'Gustavo_Henrique',
#  'Vitor_Roque',
#  'Vitória_do_Reino_Unido',
#  'Copa_do_Brasil_de_Futebol',
#  'Pitaia',
#  'Gabriel_Medina',
#  'Belo_Horizonte',
#  'Novas_sete_maravilhas_do_mundo',
#  'Língua_portuguesa',
#  'Jason_Statham',
#  'Premier_League',
#  'Twitch',
#  'Exu_de_Umbanda',
#  'Futebol',
#  'Bruce_Willis',
#  'Google_Tradutor',
#  'Turquia',
#  'Chelsea_Football_Club',
#  'Timothée_Chalamet',
#  'Ghislaine_Maxwell',
#  'Fernanda_Montenegro',
#  'X',
#  'BDSM',
#  'Mia_Goth',
#  'União_Soviética',
#  'The_Pirate_Bay',
#  'Clube_Atlético_Mineiro',
#  'Dimitri_Payet',
#  'Enrique_Díaz',
#  'Zeus',
#  'Associazione_Calcio_Milan',
#  'Moçambique',
#  'Novak_Djokovic',
#  'Eleição_presidencial_dos_Estados_Unidos_em_2024',
#  'Zinédine_Zidane',
#  'Rio_Grande_do_Sul',
#  'Ares',
#  'Tom_Cruise',
#  'Kanye_West',
#  'We_Are_the_World',
#  'Carlo_Ancelotti',
#  'Yuri_Alberto',
#  'Irã',
#  'Puma_Punku',
#  'Rogério_Ceni',
#  'Maria_Antonieta',
#  'Liverpool_Football_Club',
#  'Primeira_Liga',
#  'Juan_Carlos_Osorio',
#  'Luis_Alberto_Suárez',
#  'Osama_bin_Laden',
#  'Ana_Catarina_Afonso',
#  'Andando_nas_Nuvens',
#  'XXXTentacion',
#  'Índia',
#  'Ruy_Mingas',
#  'Alaqua_Cox',
#  'Comunismo',
#  'Rio_de_Janeiro_(estado)',
#  'Nova_Iorque',
#  'Aldemir_Ferreira',
#  'Lamborghini',
#  'Pará',
#  'TikTok',
#  'Michael_Schumacher',
#  'Ryan_Gosling',
#  'Chico_Díaz',
#  'Lista_de_países_por_população',
#  'Zico',
#  'Lista_de_episódios_de_One_Piece',
#  'Copa_Libertadores_da_América',
#  'Tottenham_Hotspur_Football_Club',
#  'Paul_Walker',
#  'Fernanda_Torres',
#  'João_Monteiro',
#  'Zé_Pelintra',
#  'Misoginia',
#  'Playboy_(Brasil)',
#  'Lista_de_países_por_Índice_de_Desenvolvimento_Humano',
#  'Miguel_(arcanjo)',
#  'Papa_Francisco',
#  'Área_51',
#  'Garrincha',
#  'Andressa_Urach',
#  'Império_Romano',
#  'Nelson_Mandela',
#  'Freddie_Mercury',
#  'Zezé_Di_Camargo',
#  'Telegram',
#  'Gisele_Bündchen',
#  'Alexandre,_o_Grande',
#  'Nicolás_de_la_Cruz',
#  'Glória_Pires',
#  'Chega',
#  'Kieran_Culkin',
#  'Lista_de_partidos_políticos_do_Brasil',
#  'Emma_Stone',
#  'Associação_Portuguesa_de_Desportos',
#  'Batalha_de_Waterloo',
#  'Daniel_Noboa',
#  'Abel_Ferreira',
#  'Ferruccio_Lamborghini',
#  'Assassinato_de_Dee_Dee_Blanchard',
#  'Europa',
#  'Carles_Puigdemont',
#  'Maestro_(filme)',
#  'Dragon_Ball_(série)',
#  'Campeonato_Italiano_de_Futebol_–_Série_A',
#  'Audax_Rio_de_Janeiro_Esporte_Clube',
#  'Ibrachina_Futebol_Clube',
#  'Luanda',
#  'Guilherme,_Príncipe_de_Gales',
#  'Supernatural_(série_de_televisão)',
#  'Manchester_United_Football_Club',
#  'Lista_das_contas_mais_seguidas_no_Instagram',
#  'Bahia',
#  'Luxemburgo',
#  'Estados_dos_Estados_Unidos',
#  'Morangos_com_Açúcar_(2023)',
#  'Adriano_Imperador',
#  'Paquistão',
#  'Getúlio_Vargas',
#  'National_Football_League',
#  'Claudinho_(cantor)',
#  'Santa_Catarina',
#  'Itaú_Unibanco',
#  'Porto_Seguro',
#  'Saquê',
#  'Copa_do_Brasil_de_Futebol_de_2024',
#  'Jão',
#  'A_Sociedade_da_Neve',
#  'Lauana_Prado',
#  'Pedro_Raul',
#  'True_Detective',
#  'Estoicismo',
#  'Canadá',
#  'Caravela-portuguesa',
#  'Lista_de_unidades_federativas_do_Brasil_por_população',
#  'Recife',
#  'Keanu_Reeves',
#  'E',
#  'Austrália',
#  'Miklós_Fehér',
#  'Yu_Yu_Hakusho',
#  'Theresa_Fonseca',
#  'Robert_Lewandowski',
#  'Campeonato_Paulista_de_Futebol_de_2024',
#  'Edgar_Allan_Poe',
#  'Lista_de_municípios_do_Brasil_por_população',
#  'Zacarias_(comediante)',
#  'Julia_Roberts',
#  'V_(artista)',
#  'Ángel_Di_María',
#  'Ana_da_Grã-Bretanha',
#  'Roblox',
#  'Sexo_Frágil',
#  'Tom_Brady',
#  'Amazonas_Futebol_Clube',
#  'Harry_Potter',
#  'Torre_Eiffel',
#  'Lista_dos_canais_com_mais_inscritos_do_YouTube',
#  'Copa_do_Nordeste_de_Futebol_de_2024',
#  'Jodie_Foster',
#  'Calendário_chinês',
#  'Bitcoin',
#  'Afrodite',
#  'Michael_Jordan',
#  'Eco_(Marvel_Comics)',
#  'Andes',
#  'Manu_Bahtidão',
#  'Igreja_Católica',
#  'Jogos_Olímpicos_de_Verão_de_2024',
#  'Salvador',
#  'Dwayne_Johnson',
#  'L',
#  'Amy_Winehouse',
#  'Marcos_Leonardo',
#  'Meta_Platforms',
#  'BTS',
#  'Primeiro_Comando_da_Capital',
#  'Joe_Biden',
#  'Ucrânia',
#  'Pedro_I_do_Brasil',
#  'The_Walking_Dead_(série_de_televisão)',
#  'David_Bowie',
#  'Samuel_Reoli',
#  'Game_of_Thrones',
#  'Marilyn_Monroe',
#  'The_Office_(Estados_Unidos)',
#  'IPhone',
#  'Robert_Renan',
#  'Sylvester_Stallone',
#  'Minecraft',
#  'Copa_do_Nordeste_de_Futebol',
#  'Raul_Seixas',
#  'Esporte_Clube_Vitória',
#  'Jezabel',
#  'Face',
#  'Inteligência_artificial',
#  'Bebeto',
#  'Fuzuê',
#  'Pinterest',
#  'Lista_de_países_por_índice_de_poder_militar',
#  'Javier_Milei',
#  'Evaristo_de_Macedo',
#  'V',
#  'Flávio_Dino',
#  'Copa_do_Mundo_FIFA_de_2026',
#  'André_Villas-Boas',
#  'John_F._Kennedy',
#  'Barcelona',
#  'Lilith',
#  'Lisboa',
#  'Melody_(cantora)',
#  'Juventus_Football_Club',
#  'Brad_Pitt',
#  'Maria_Luísa_de_Áustria',
#  'Futebol_Clube_do_Porto',
#  'Prime_Video',
#  'Marília_Mendonça',
#  'Dermatite_atópica',
#  'Fortaleza',
#  'Copa_do_Mundo_de_Clubes_da_FIFA',
#  'Catarina,_Princesa_de_Gales',
#  'Breaking_Bad',
#  'Alexandre_Pato',
#  'Vladimir_Putin',
#  'Pedro_II_do_Brasil',
#  'Alfabeto_grego',
#  'Lista_de_prenomes_mais_comuns_no_Brasil',
#  'Daniil_Medvedev',
#  'Gato',
#  'Alice_Braga',
#  'Festival_Folclórico_de_Parintins',
#  'Lucas_Beraldo',
#  'Adan_Canto',
#  'Rodrygo_Goes',
#  'Naruto',
#  'Atena',
#  'Yeferson_Soteldo',
#  'George_Foreman',
#  'Tony_Ramos',
#  'Suécia',
#  'Renato_Augusto',
#  'Copa_da_Ásia_de_2023',
#  'Margot_Robbie',
#  'Elias_Maluco',
#  'Jeffrey_Dahmer',
#  'Thiago_Maia',
#  'Diego_Palacios',
#  'Naufrágio_do_RMS_Titanic',
#  'Belém_(Pará)',
#  'Os_Travessos',
#  'Macaulay_Culkin',
#  'Patrícia_França',
#  'Muricy_Ramalho',
#  'Bradley_Cooper',
#  'Rivaldo',
#  'Campeonato_Carioca_de_Futebol_de_2024',
#  'Chorão_(cantor)',
#  'Lista_de_papas',
#  'Jennifer_Lawrence',
#  'Espírito_Santo_(estado)',
#  'No_Rancho_Fundo_(telenovela)',
#  'África',
#  'Cândido_Costa',
#  'Lista_das_cidades_mais_populosas_do_mundo',
#  'Jacob_Elordi',
#  'Supremo_Tribunal_Federal',
#  'The_Big_Bang_Theory',
#  'Júlio_César',
#  'Wonka_(filme)',
#  'Partido_Popular_Monárquico',
#  'Renato_Aragão',
#  'Uruguai',
#  'Gloria_Groove',
#  'Shopee',
#  'André_Felipe_Ribeiro_de_Souza',
#  'Anunáqui',
#  'Félix_Torres',
#  'Carmen_Miranda',
#  'Buchecha',
#  'Antoine_Griezmann',
#  'Xabi_Alonso',
#  'Lista_de_municípios_de_Santa_Catarina_por_população',
#  'David_Beckham',
#  'Enzo_Ferrari',
#  'Thiago_Alcântara',
#  'Lista_de_partes_da_anatomia_humana',
#  'Cane_corso',
#  'Bundesliga',
#  'Myrtle_Corbin',
#  'Ivete_Sangalo',
#  'Eminem',
#  'Guiné-Bissau',
#  'América_Latina',
#  'Aryna_Sabalenka',
#  'Amado_Batista',
#  'Microsoft_Hotmail',
#  'City_Football_Group',
#  'Róger_Guedes',
#  'Josef_Stalin',
#  'António_de_Oliveira_Salazar',
#  'Herbert_José_de_Sousa',
#  'Ipira',
#  'Patrick_Mahomes',
#  'Lista_de_municípios_do_Brasil_por_população_(2022)',
#  'Renato_Russo',
#  'Cão',
#  'Elton_John',
#  'Jorge_VI_do_Reino_Unido',
#  'Guiné_Equatorial',
#  'Goiânia',
#  'Lista_de_telenovelas_das_seis_da_TV_Globo',
#  'Geração_Z',
#  'O',
#  'El_Chavo_del_Ocho',
#  'Football_Club_Internazionale_Milano',
#  'Gal_Gadot',
#  'Revolução_Francesa',
#  'México',
#  'Robert_Downey_Jr.',
#  'Tarsila_do_Amaral',
#  'FC_Bayern_München',
#  'Incêndio_na_boate_Kiss',
#  'Marcos_Palmeira',
#  'Club_Athletico_Paranaense',
#  'Hilda_Furacão_(minissérie)',
#  'Eusébio',
#  'The_Beatles',
#  'Apolo',
#  'Fentanil',
#  'Pedro_(apóstolo)',
#  'Ariana_Grande',
#  'Taça_de_Portugal',
#  'Endrick',
#  'Demissexualidade',
#  'Tião_Carreiro',
#  'Campeonato_Baiano_de_Futebol',
#  'Brasileiros',
#  "Grey's_Anatomy",
#  'Lista_de_símbolos_matemáticos',
#  'Athletic_Club',
#  'Campinas',
#  'Costa_do_Marfim',
#  'José_Wilker',
#  'Paraná',
#  'Música',
#  'A_Máscara_(programa_de_televisão)',
#  'Lista_de_número_de_títulos_nacionais_e_internacionais_conquistados_por_times_brasileiros_de_futebol',
#  'Egito',
#  'Cristo_Redentor',
#  'Aquaman',
#  'Daniel_Alves',
#  'Açores',
#  'Al-Nassr_Football_Club',
#  'Novo_Banco',
#  'C_(linguagem_de_programação)',
#  'Dólar_dos_Estados_Unidos',
#  'União_Europeia',
#  'Lista_de_municípios_do_Rio_Grande_do_Sul_por_população',
#  'Campeonato_Brasileiro_de_Futebol_de_2024_-_Série_D',
#  'Porto',
#  'Brasil_Online',
#  'Finlândia',
#  'Leonardo_Vieira',
#  'Lista_de_países_e_territórios_por_área',
#  'Ku_Klux_Klan',
#  'Big_Brother_Brasil_21',
#  "McDonald's",
#  'Rafael_Nadal',
#  'Madonna',
#  'Sophie_Charlotte',
#  'Big_Brother_Brasil_22',
#  'Islândia',
#  'Kim_Jong-un',
#  'Thiago_Silva',
#  'Pernambuco',
#  'Narcisa_Tamborindeguy',
#  'Sodomia',
#  'Inglaterra',
#  'Joinville',
#  'Copa_da_Liga_Inglesa',
#  'Fernando_Collor',
#  'Tatá_Werneck',
#  'Prozis',
#  'Roma',
#  'Lista_de_campeões_da_Fórmula_1',
#  'Luan_Guilherme_de_Jesus_Vieira',
#  'Bíblia',
#  'Benedito_Ruy_Barbosa',
#  'Charlie_Sheen',
#  'Mike_Tyson',
#  'Lampião_(cangaceiro)',
#  'Euro',
#  'Serra_da_Estrela',
#  'Diego_Costa',
#  'Ribeirão_Preto',
#  'Século_XVI',
#  'São_José_dos_Campos',
#  'Alexandre_de_Moraes',
#  'Andorra',
#  'LinkedIn',
#  'Alfabeto',
#  'Hulk_(futebolista)',
#  'Berlim_(série)',
#  'Whitney_Houston',
#  'Robin_Williams',
#  'Reacher_(série_de_televisão)',
#  'Arábia_Saudita',
#  'Sebastião_de_Narbona',
#  'Lista_das_pessoas_mais_ricas_do_Brasil',
#  'Christopher_Nolan',
#  'Malta',
#  'Copa_São_Paulo_de_Futebol_Júnior_de_2023',
#  'Posídon',
#  'Liga_Europa_da_UEFA',
#  'Mamadou_Sakho',
#  'Ednaldo_Rodrigues',
#  'Bandeira_do_Brasil',
#  'Caio_Paulista',
#  'Magnus_Carlsen',
#  'Girona',
#  'Succession_(série_de_televisão)',
#  'Magazine_Luiza',
#  'Giorgian_De_Arrascaeta',
#  'Mean_Girls',
#  'Discord',
#  'Aliança_Democrática_(2024)',
#  'Lady_Gaga',
#  'Mahatma_Gandhi',
#  'Campeonato_Mineiro_de_Futebol',
#  'Chester_Bennington',
#  'Tailândia',
#  'Martin_Scorsese',
#  'Philippe_Coutinho',
#  'Ponto_de_interrogação',
#  'T-Rex_Game',
#  'Kimetsu_no_Yaiba',
#  'Samael',
#  'Filipe,_Duque_de_Edimburgo',
#  'Mickey_Mouse',
#  'Paris_Saint-Germain_Football_Club',
#  'Bom_Dia,_Verônica',
#  'Exército_Brasileiro',
#  'Lista_de_telenovelas_das_oito_da_TV_Globo',
#  'Dua_Lipa',
#  'Porto_Alegre',
#  'Igreja_Adventista_do_Sétimo_Dia',
#  'Ornitorrinco',
#  'Steve_Jobs',
#  'Copa_Libertadores_da_América_de_2024',
#  'Bayer_04_Leverkusen',
#  'Muhammad_Ali',
#  'Campeonato_Pernambucano_de_Futebol',
#  'Massagem_tântrica',
#  'Horóscopo_chinês',
#  'Taj_Mahal',
#  'Star_Wars',
#  'Juan_Paiva',
#  'Sodoma_e_Gomorra',
#  'Noruega',
#  'Lenin',
#  'Congregação_Cristã_no_Brasil',
#  'Organização_das_Nações_Unidas',
#  'Harry_Kane',
#  'Partido_Liberal_(2006)',
#  'Deborah_Secco',
#  'Frida_Kahlo',
#  'M',
#  'Angelina_Jolie',
#  'Peaky_Blinders',
#  'Kevin_De_Bruyne',
#  'Beyoncé',
#  'Jackie_Chan',
#  'Lauryn_Hill',
#  'Hwang_In-yeop',
#  'John_Lennon',
#  'Bombardeamentos_atômicos_de_Hiroshima_e_Nagasaki',
#  'Peaky_Blinders_(série_de_televisão)',
#  'Fernando_Diniz',
#  'Club_Atlético_de_Madrid',
#  'Mulher_trans',
#  'Eduardo_VIII_do_Reino_Unido',
#  'Leonardo_da_Vinci',
#  'Mohamed_Salah',
#  'Luís_Montenegro',
#  'Sérgio_Reoli',
#  'Carlos_Villagrán',
#  'Jô_(futebolista)',
#  'Equatorial_Energia',
#  'Maria_(mãe_de_Jesus)',
#  'Renato_Gaúcho',
#  'Felicia_Montealegre',
#  'Marrocos',
#  'Acidente_do_Learjet_25D_prefixo_PT-LSD_em_1996',
#  'Oscar_de_melhor_filme',
#  'Equidna_(mitologia)',
#  'Débora_Ozório',
#  'Aquário_(astrologia)',
#  'Abraão',
#  'Kurt_Cobain',
#  'Diego_Maradona',
#  'Interstellar',
#  'Hermes',
#  'Billie_Eilish',
#  'Emmanuel_Macron',
#  'José_Sarney',
#  'Frederico_X_da_Dinamarca',
#  'Roberto_Gómez_Bolaños',
#  'Mano_Menezes',
#  'Denzel_Washington',
#  'Alessandra_Negrini',
#  'Relógio_do_Juízo_Final',
#  'Kylie_Jenner',
#  'República_Democrática_do_Congo',
#  'Ricardo_Cappelli',
#  'Bruna_Marquezine',
#  'Império_Otomano',
#  'Afonso_Henriques',
#  'Jorge_V_do_Reino_Unido',
#  'Isis_Valverde',
#  'Johnny_Depp',
#  'Língua_inglesa',
#  'João_Pessoa',
#  'Riley_Keough',
#  'Travessia_(telenovela)',
#  'Guilherme_de_Pádua',
#  'André,_Duque_de_Iorque',
#  'Tiramisù',
#  'Jennifer_Lopez',
#  'Matilde_Reymão',
#  'Justin_Bieber',
#  'Zlatan_Ibrahimović',
#  'Bélgica',
#  'Associazione_Sportiva_Roma',
#  'Cauã_Reymond',
#  'Presidente_dos_Estados_Unidos',
#  'Raniele',
#  'Società_Sportiva_Calcio_Napoli',
#  'Débora_Falabella',
#  'Zorro',
#  'Johan_Cruijff',
#  'Luís_de_Camões',
#  'Sven-Göran_Eriksson',
#  'Paris',
#  'Adriana_Esteves',
#  'The_Vampire_Diaries_(série_de_televisão)',
#  'Ken_Miles',
#  'Londres',
#  'Partido_dos_Trabalhadores',
#  'Rogelio_Funes_Mori',
#  'Anne_Frank',
#  'Sebastião_Bugalho',
#  'Lista_de_telenovelas_das_sete_da_TV_Globo',
#  'Young_Sheldon',
#  'Lista_dos_100_maiores_artistas_da_música_brasileira_pela_Rolling_Stone_Brasil',
#  'Tetê_Espíndola',
#  'Gal_Costa',
#  'Maria_Madalena',
#  'Cristianismo',
#  'Tim_Maia',
#  'Bruce_Lee',
#  'Jason_Momoa',
#  'Colômbia',
#  'Mato_Grosso_do_Sul',
#  'Globoplay',
#  'Rodrigo_Santoro',
#  'Winston_Churchill',
#  'Morangos_com_Açúcar',
#  'João_Carreiro',
#  'Cafu',
#  'Dodi_Al-Fayed',
#  'Papa_João_Paulo_II',
#  'Fernandinho_Beira-Mar',
#  'Salomão',
#  'Aston_Villa_Football_Club',
#  'Campo_Grande_(Mato_Grosso_do_Sul)',
#  'Chico_Xavier',
#  'Pantanal_(2022)',
#  'Marina_Ruy_Barbosa',
#  'Juliana_Paes',
#  'Coliseu',
#  'Toni_Kroos',
#  'The_Fast_and_the_Furious_(franquia)',
#  'Direito_de_Amar',
#  'Rita_Lee',
#  'Marielle_Franco',
#  'Rodrigo_Garro',
#  'Homem-Aranha',
#  'Indonésia',
#  'Copa_América',
#  'Kobe_Bryant',
#  'Hong_Kong',
#  'Ana_Hickmann',
#  'Cronos',
#  'Clint_Eastwood',
#  'Roberto_Carlos_(futebolista)',
#  'Curaçau',
#  'Ary_Fontoura',
#  'Lista_de_posições_sexuais',
#  'Dia_dos_Namorados',
#  'Spotify',
#  'Doença_de_Crohn',
#  'Etiópia',
#  'Mórmon',
#  'True_Beauty',
#  'Califórnia',
#  'Gonzalo_Mastriani',
#  'Jorge_Nuno_Pinto_da_Costa',
#  'Santos',
#  'Melhor_Jogador_do_Mundo_pela_FIFA',
#  'Cuba',
#  'Isabel_Bowes-Lyon',
#  'Humano',
#  'Grécia',
#  'Jonathan_Roumie',
#  'Maria_Fernanda_Cândido',
#  'Sporting_Clube_de_Braga',
#  'Robinho',
#  'Maria_Clara_Spinelli',
#  'David_Terans',
#  'Jeon_Jung-kook',
#  'Sevilla_Fútbol_Club',
#  'Leila_Pereira',
#  'Sydney_Sweeney',
#  'Xavi',
#  'General_Motors',
#  'Lista_de_municípios_do_Brasil_por_PIB',
#  'Ceará',
#  'Jeremy_Allen_White',
#  'Irlanda',
#  'Perseu',
#  'Janeiro',
#  'Óscar',
#  'Ditadura_militar_brasileira',
#  'W',
#  'Céline_Dion',
#  'Illuminati',
#  'Hungria',
#  'Folia_de_Reis',
#  'Maragogi',
#  'Umbanda',
#  '2023',
#  'Kiko_Zambianchi',
#  'Lana_Del_Rey',
#  'Serena_Williams',
#  'Vikings_(série_de_televisão)',
#  'Ben_Affleck',
#  'Suits',
#  'Frederico,_Príncipe_Herdeiro_da_Dinamarca',
#  'Steam',
#  'Karim_Benzema',
#  'Lista_de_municípios_de_São_Paulo',
#  'Kid_Bengala',
#  'Ramessés_II',
#  'Eleições_legislativas_portuguesas_de_2022',
#  '8_de_janeiro',
#  'João_Guilherme_(ator)',
#  'Società_Sportiva_Lazio',
#  'Júlio_Rasec',
#  'História_de_Amor',
#  'Avenida_Brasil_(telenovela)',
#  'Os_Cavaleiros_do_Zodíaco',
#  'Marcelo_Rebelo_de_Sousa',
#  'Gabriel_Attal',
#  'Thammy_Miranda',
#  'Larissa_Manoela',
#  'Val_Kilmer',
#  'T',
#  'Antártida']

# %% [markdown]
# ### d. Function that returns a Dataframe containing the views of the most viewed pt_wiki articles for January & February

# %% [markdown]
# ### d (i). Showing the dataframe containing the views of the most viewed pt_wiki articles for January & February

# %%
async def fetch(date, url, article_views_df, sorted_articles_jan_feb):
    """
    Async function to fetch data from the given URL and update the DataFrame.
    
    NB: This function uses asynchronous programming to cater for the blocking time
        in the large amounts of requests to be executed for each
        article all through the days in January and February. 
        
        Computation time was reduced from >2hrs to ~5secs
    """
    user_agent = "nelson.ifechukwu@gmail.com"
    headers = {"User-Agent": user_agent}

    # Make an asynchronous request to the specified URL
    try:
        async with httpx.AsyncClient() as client:
            response = await client.get(url, headers=headers)
            data = response.json()

            # Check if the response contains the expected 'items' key and has non-empty data
            if 'items' in data and data['items']:
                info = data['items'][0]
                
                # Check if the project is 'pt.wikipedia' (Portuguese Wikipedia)
                if info['project'] == 'pt.wikipedia':
                    
                    # Iterate through each article in the response data per the timestamp
                    for article_info in info['articles']:
                        
                        #check if the article is among the most viewed pt_wiki articles ( => top 1000)
                        if article_info['article'] in sorted_articles_jan_feb:      
                            
                            # Update the DataFrame with the number of views for the article on the specified date
                            article_views_df.at[article_info['article'], date.strftime('%Y-%m-%d')] = article_info['views']
            else:
                # Log a warning if the expected 'items' key is not found in the response
                logging.warning(f"No 'items' key found in response: {data}, Status code: {response.status_code}")
    
    except httpx.RequestError as e:
        # Log an error if there is an issue with the HTTP request
        logging.error(f"Error fetching url-{url}: {e}")

async def most_viewed_ptwiki_jan_feb_per_day() -> pd.DataFrame:
    """
    Get the most viewed articles in the Portuguese Wikipedia
    for the specified months, organized by day.
    
    Returns:
    - pd.DataFrame: A DataFrame containing the articles as the row index and dates
      as the column headers with each cell containing the number of views of the article
      on the specified date.
    """ 

    # Define formatted date range to fetch from using the url
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 2, 29)

    # Get a sorted list of the most viewed articles in Portuguese Wiki in January & February
    sorted_articles_jan_feb = most_viewed_ptwiki(["January", "February"])

    #remove false positives
    sorted_articles_jan_feb = remove_false_positives(sorted_articles_jan_feb)

    # Define a date-range for the DataFrame column headers
    date_range = [(start_date + timedelta(days=x)).strftime('%Y-%m-%d') for x in range((end_date - start_date).days + 1)]
    
    # Initialize the DataFrame
    article_views_df = pd.DataFrame(index=sorted_articles_jan_feb, columns=date_range)

    # Get all the URLs per article in sorted_articles_jan_feb (to get their views from Jan to Feb)
    urls = []
    current_date = start_date
    while current_date <= end_date:
        urls.append((current_date, f"https://wikimedia.org/api/rest_v1/metrics/pageviews/top/pt.wikipedia/all-access/{current_date.strftime('%Y/%m/%d')}"))
        current_date += timedelta(days=1)
        
    # Split the async operations into batches
    tasks = [fetch(url_detail[0], url_detail[1], article_views_df, sorted_articles_jan_feb) for url_detail in urls]
    await asyncio.gather(*tasks)

    return article_views_df

# %%
# allow the async event loop to run in the Jupyter cell event loop
nest_asyncio.apply()

# call most_viewed_ptwiki_jan_feb_per_day asynchronously 
top_viewed_dataframe = asyncio.run(most_viewed_ptwiki_jan_feb_per_day())
top_viewed_dataframe
# Out:
#                                     2024-01-01 2024-01-02 2024-01-03  \
# Facebook                                 13195      14024      14480
# Fotos_dos_Mamonas_Assassinas_mortos        NaN        NaN      12913
# Cleópatra                                 3432       3420       3542
# Porno_Graffitti                            NaN        NaN        NaN
# ChatGPT                                   1274       2484       3258
# ...                                        ...        ...        ...
# Banana                                     NaN        NaN        NaN
# Ana_de_Armas                               NaN        NaN        NaN
# Idade_Média                                NaN        NaN        NaN
# Chico_Buarque                              552        NaN        NaN
# Juscelino_Kubitschek                       NaN        NaN        NaN
#
#                                     2024-01-04 2024-01-05 2024-01-06  \
# Facebook                                 14609      13584      12304
# Fotos_dos_Mamonas_Assassinas_mortos      15280      11216      46426
# Cleópatra                                 3642       3922       3924
# Porno_Graffitti                            NaN        NaN        NaN
# ChatGPT                                   2657       2408       1989
# ...                                        ...        ...        ...
# Banana                                     NaN        NaN        NaN
# Ana_de_Armas                               NaN        NaN        NaN
# Idade_Média                                NaN        NaN        NaN
# Chico_Buarque                              NaN        NaN        NaN
# Juscelino_Kubitschek                       NaN        NaN        NaN
#
#                                     2024-01-07 2024-01-08 2024-01-09  \
# Facebook                                 12509      14081      15977
# Fotos_dos_Mamonas_Assassinas_mortos      32110      26610      17609
# Cleópatra                                 3801       4229       4250
# Porno_Graffitti                            NaN        NaN        NaN
# ChatGPT                                   2178       7203       9411
# ...                                        ...        ...        ...
# Banana                                     NaN        NaN        NaN
# Ana_de_Armas                               747        NaN        NaN
# Idade_Média                                NaN        NaN        NaN
# Chico_Buarque                              NaN        NaN        NaN
# Juscelino_Kubitschek                       NaN        NaN        NaN
#
#                                     2024-01-10  ... 2024-02-20 2024-02-21  \
# Facebook                                 14702  ...      15625      15662
# Fotos_dos_Mamonas_Assassinas_mortos      14837  ...       4998       4538
# Cleópatra                                 4168  ...      13758      14087
# Porno_Graffitti                            NaN  ...        NaN        NaN
# ChatGPT                                   9114  ...      11161      11377
# ...                                        ...  ...        ...        ...
# Banana                                     NaN  ...        NaN        NaN
# Ana_de_Armas                               NaN  ...        NaN        NaN
# Idade_Média                                NaN  ...        651        704
# Chico_Buarque                              NaN  ...        NaN        597
# Juscelino_Kubitschek                       613  ...        558        567
#
#                                     2024-02-22 2024-02-23 2024-02-24  \
# Facebook                                 14481      13224      12502
# Fotos_dos_Mamonas_Assassinas_mortos       4762       5351       7864
# Cleópatra                                14285      14373      14599
# Porno_Graffitti                            NaN        NaN        NaN
# ChatGPT                                  11023      10056       6763
# ...                                        ...        ...        ...
# Banana                                     NaN        NaN        NaN
# Ana_de_Armas                               NaN        NaN        NaN
# Idade_Média                                697        538        NaN
# Chico_Buarque                              565        540        NaN
# Juscelino_Kubitschek                       NaN        555        NaN
#
#                                     2024-02-25 2024-02-26 2024-02-27  \
# Facebook                                 11664      15940      17258
# Fotos_dos_Mamonas_Assassinas_mortos       5264       3340       2732
# Cleópatra                                14139      14269      14999
# Porno_Graffitti                            NaN        NaN        NaN
# ChatGPT                                   6857      12084      13414
# ...                                        ...        ...        ...
# Banana                                     NaN        NaN        NaN
# Ana_de_Armas                               NaN        NaN        NaN
# Idade_Média                                NaN        749        752
# Chico_Buarque                              NaN        NaN        NaN
# Juscelino_Kubitschek                       NaN        659        548
#
#                                     2024-02-28 2024-02-29
# Facebook                                 15484      15548
# Fotos_dos_Mamonas_Assassinas_mortos       2665       3136
# Cleópatra                                14999      14375
# Porno_Graffitti                            NaN        NaN
# ChatGPT                                  13736      13466
# ...                                        ...        ...
# Banana                                     NaN        NaN
# Ana_de_Armas                               NaN        NaN
# Idade_Média                                675        624
# Chico_Buarque                              666        NaN
# Juscelino_Kubitschek                       623        552
#
# [1353 rows x 60 columns]

# %% [markdown]
# ### Data visualization
#
# Here you can find the documentation for a library for a Bar Chart Race library: https://pypi.org/project/bar-chart-race.
#
# Read and understand the documentation and use this library to create a function that display an animated race chart of the dataframe you produced in the section before (*top_viewed_dataframe*).
#
# **Objective:** *(3) to create an animated visualization of the data you gathered.*

# %% [markdown]
# ### e. Visualize the data in a chart-race

# %%
# Install the bar-chart-race library to visualize the article views
# !pip install bar_chart_race
# Out:
# Requirement already satisfied: bar_chart_race in /srv/paws/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: pandas>=0.24 in /srv/paws/lib/python3.10/site-packages (from bar_chart_race) (2.2.1)
# Requirement already satisfied: matplotlib>=3.1 in /srv/paws/lib/python3.10/site-packages (from bar_chart_race) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (23.2)
# Requirement already satisfied: pillow>=8 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/paws/lib/python3.10/site-packages (from matplotlib>=3.1->bar_chart_race) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/paws/lib/python3.10/site-packages (from pandas>=0.24->bar_chart_race) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/paws/lib/python3.10/site-packages (from pandas>=0.24->bar_chart_race) (2024.1)
# Requirement already satisfied: six>=1.5 in /srv/paws/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->bar_chart_race) (1.16.0)

# %%
# Download a static FFmpeg build and add it to PATH for the bar_chart_race to execute correctly
import bar_chart_race as bcr
# %run 'util/load-ffmpeg.ipynb'
print('Done!')
# Out:
# ./ffmpeg-6.1-amd64-static/ffmpeg
# Done!

# %%
def dataframe_to_race_chart(df):
    """
    Define a function to plot the chart race from the formed dataframe.

    Parameters:
    - df (pd.DataFrame, optional): The DataFrame to be used for plotting the chart race. Default is top_viewed_dataframe.

    Returns:
    - None

    This function also cleans, filters, and prepares the DataFrame as a 'wide' data according to the bar_chart_race documentation.
    """
    # Transpose the DataFrame to make it suitable for bar_chart_race
    df = df.T
    
    # Fill NaN values with 0
    df = df.fillna(0)
    
    # Convert all values to numeric type
    df = df.apply(pd.to_numeric, errors='coerce')
    
    # Apply cumulation to show accumulating views over time
    c_df = df.cumsum(axis=0) 

    # Plot the chart race using bar_chart_race
    bcr.bar_chart_race(
        c_df,
        n_bars=8,  # Define the number of bars to be displayed
        period_length=500,  # Number of time taken per period in a frame
        steps_per_period=10,  # Number of frame steps per period
        title='Most viewed articles',  # Title of the chart
        shared_fontdict={'family': 'DejaVu Sans', 'color': '.1'},  # Define font type in the chart 
        scale='linear',
        writer=None,
        bar_label_size=7,  #Define the size of the bar labels
        tick_label_size=7,  #Define the size of the bar ticks (numbers)
        filename="chart-race.mp4",  #Define the name of the file output
        fixed_order=False,
        fixed_max=True,
        label_bars=True,
        bar_size=.95,  #define how large the bars are
        period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},  # Position and alignment of the period label
        perpendicular_bar_func='median',  # Function to calculate perpendicular bar heights
        dpi=144,  # Dots per inch
        cmap='dark2',  # Colormap for coloring bars
        fig=None,
        bar_kwargs={'alpha': .7},  # Keyword arguments for bars
        filter_column_colors=False  # Whether to filter column colors
    )

# %%
# Suppress the specific warnings when executing the bar_chart_race function 
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# Call the bar_chart_race function
dataframe_to_race_chart(df = top_viewed_dataframe)

# %%
# Display the chart race video
Video("chart-race.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
